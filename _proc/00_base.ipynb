# %% [raw]
# ---
# description: This is the base notebook for the istatapi package. It contains the code
#   to make the API calls.
# output-file: base.html
# title: Base
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(get_custom_ssl_session)
# Out:
# ---
#
# [source](https://github.com/Attol8/istatapi/blob/master/istatapi/base.py#L44){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_custom_ssl_session
#
# >      get_custom_ssl_session ()
#
# *Get a session with a custom ssl context*

# %%
#| echo: false
#| output: asis
show_doc(CustomHttpAdapter)
# Out:
# ---
#
# [source](https://github.com/Attol8/istatapi/blob/master/istatapi/base.py#L32){target="_blank" style="float:right; font-size:smaller"}
#
# ### CustomHttpAdapter
#
# >      CustomHttpAdapter (ssl_context=None, **kwargs)
#
# *Transport adapter" that allows us to use custom ssl_context.*

# %%
#| echo: false
#| output: asis
show_doc(ISTAT)
# Out:
# ---
#
# [source](https://github.com/Attol8/istatapi/blob/master/istatapi/base.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### ISTAT
#
# >      ISTAT ()
#
# *Base class that provides useful functions to communicate with ISTAT API*

# %%
#| echo: false
#| output: asis
show_doc(ISTAT._request)
# Out:
# ---
#
# [source](https://github.com/Attol8/istatapi/blob/master/istatapi/base.py#L19){target="_blank" style="float:right; font-size:smaller"}
#
# ### ISTAT._request
#
# >      ISTAT._request (path, **kwargs)
#
# *Make a request to ISTAT API given a 'path'*

# %% [markdown]
# The 'ISTAT' class already implements the 'base_url', therefore 'path' only needs to include the other parameters of the request. Here is an example of a succesful request:

# %%
istat = ISTAT()
path = "dataflow/IT1"
test_response = istat._request(path=path)
test_response
# Out:
# <Response [200]>
