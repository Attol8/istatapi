# %% [raw]
# ---
# description: Utility functions used in the notebooks
# output-file: utils.html
# title: Utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(strip_ns)
# Out:
# def strip_ns(
#     tree
# ):
# """strip all the namespaces from `tree`"""

# %%
#| echo: false
#| output: asis
show_doc(make_tree)
# Out:
# def make_tree(
#     response
# ):
# """Make an `ElementTree` from the text of an XML `response`"""
