# %% [raw]
# ---
# description: Utility functions used in the notebooks
# output-file: utils.html
# title: Utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(strip_ns)
# Out:
# ---
#
# [source](https://github.com/Attol8/istatapi/blob/master/istatapi/utils.py#L16){target="_blank" style="float:right; font-size:smaller"}
#
# ### strip_ns
#
# >      strip_ns (tree)
#
# strip all the namespaces from `tree`

# %%
#| echo: false
#| output: asis
show_doc(make_tree)
# Out:
# ---
#
# [source](https://github.com/Attol8/istatapi/blob/master/istatapi/utils.py#L11){target="_blank" style="float:right; font-size:smaller"}
#
# ### make_tree
#
# >      make_tree (response)
#
# Make an `ElementTree` from the text of an XML `response`
